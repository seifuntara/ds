# %% [markdown]
# # Project 7: Star Wars Characters
# ## Data Cleaning (Surveys)
#
# In this project, we will particularly use data cleaning analysis methods to perform data visualization on data from surveys. In this case, we will use Star Wars survey which include rates on Star Wars characters.
#
# Datasets used in this project from:
# * [Star Wars Survey](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)

# %% [markdown]
# We will first import data and rearrange the columns:

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("star_wars.csv",header=None,na_values=['Unfamiliar (N/A)'])
df.head()
# Out:
#              0                                                  1   \
# 0  RespondentID  Have you seen any of the 6 films in the Star W...
# 1           NaN                                           Response
# 2  3292879998.0                                                Yes
# 3  3292879538.0                                                 No
# 4  3292765271.0                                                Yes
#
#                                                   2   \
# 0  Do you consider yourself to be a fan of the St...
# 1                                           Response
# 2                                                Yes
# 3                                                NaN
# 4                                                 No
#
#                                                   3   \
# 0  Which of the following Star Wars films have yo...
# 1           Star Wars: Episode I  The Phantom Menace
# 2           Star Wars: Episode I  The Phantom Menace
# 3                                                NaN
# 4           Star Wars: Episode I  The Phantom Menace
#
#                                             4   \
# 0                                   Unnamed: 4
# 1  Star Wars: Episode II  Attack of the Clones
# 2  Star Wars: Episode II  Attack of the Clones
# 3                                          NaN
# 4  Star Wars: Episode II  Attack of the Clones
#
#                                             5   \
# 0                                   Unnamed: 5
# 1  Star Wars: Episode III  Revenge of the Sith
# 2  Star Wars: Episode III  Revenge of the Sith
# 3                                          NaN
# 4  Star Wars: Episode III  Revenge of the Sith
#
#                                   6   \
# 0                         Unnamed: 6
# 1  Star Wars: Episode IV  A New Hope
# 2  Star Wars: Episode IV  A New Hope
# 3                                NaN
# 4                                NaN
#
#                                              7   \
# 0                                    Unnamed: 7
# 1  Star Wars: Episode V The Empire Strikes Back
# 2  Star Wars: Episode V The Empire Strikes Back
# 3                                           NaN
# 4                                           NaN
#
#                                          8   \
# 0                                Unnamed: 8
# 1  Star Wars: Episode VI Return of the Jedi
# 2  Star Wars: Episode VI Return of the Jedi
# 3                                       NaN
# 4                                       NaN
#
#                                                   9   ...              28  \
# 0  Please rank the Star Wars films in order of pr...  ...     Unnamed: 28
# 1           Star Wars: Episode I  The Phantom Menace  ...            Yoda
# 2                                                  3  ...  Very favorably
# 3                                                NaN  ...             NaN
# 4                                                  1  ...             NaN
#
#                                  29  \
# 0       Which character shot first?
# 1                          Response
# 2  I don't understand this question
# 3                               NaN
# 4  I don't understand this question
#
#                                              30  \
# 0  Are you familiar with the Expanded Universe?
# 1                                      Response
# 2                                           Yes
# 3                                           NaN
# 4                                            No
#
#                                                   31  \
# 0  Do you consider yourself to be a fan of the Ex...
# 1                                           Response
# 2                                                 No
# 3                                                NaN
# 4                                                NaN
#
#                                                   32        33        34  \
# 0  Do you consider yourself to be a fan of the St...    Gender       Age
# 1                                           Response  Response  Response
# 2                                                 No      Male     18-29
# 3                                                Yes      Male     18-29
# 4                                                 No      Male     18-29
#
#                  35                  36                        37
# 0  Household Income           Education  Location (Census Region)
# 1          Response            Response                  Response
# 2               NaN  High school degree            South Atlantic
# 3      $0 - $24,999     Bachelor degree        West South Central
# 4      $0 - $24,999  High school degree        West North Central
#
# [5 rows x 38 columns]

# %%
col=['Gender']+list(df.loc[1,15:28])
df=df.loc[2:, [33]+list(np.arange(15,29))]
df.columns=col
df.head()
# Out:
#   Gender            Han Solo      Luke Skywalker Princess Leia Organa  \
# 2   Male      Very favorably      Very favorably       Very favorably
# 3   Male                 NaN                 NaN                  NaN
# 4   Male  Somewhat favorably  Somewhat favorably   Somewhat favorably
# 5   Male      Very favorably      Very favorably       Very favorably
# 6   Male      Very favorably  Somewhat favorably   Somewhat favorably
#
#        Anakin Skywalker      Obi Wan Kenobi   Emperor Palpatine  \
# 2        Very favorably      Very favorably      Very favorably
# 3                   NaN                 NaN                 NaN
# 4    Somewhat favorably  Somewhat favorably                 NaN
# 5        Very favorably      Very favorably  Somewhat favorably
# 6  Somewhat unfavorably      Very favorably    Very unfavorably
#
#           Darth Vader                             Lando Calrissian  \
# 2      Very favorably                                          NaN
# 3                 NaN                                          NaN
# 4                 NaN                                          NaN
# 5      Very favorably                           Somewhat favorably
# 6  Somewhat favorably  Neither favorably nor unfavorably (neutral)
#
#               Boba Fett               C-3P0               R2 D2  \
# 2                   NaN      Very favorably      Very favorably
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# 5  Somewhat unfavorably      Very favorably      Very favorably
# 6        Very favorably  Somewhat favorably  Somewhat favorably
#
#       Jar Jar Binks       Padme Amidala                Yoda
# 2    Very favorably      Very favorably      Very favorably
# 3               NaN                 NaN                 NaN
# 4               NaN                 NaN                 NaN
# 5    Very favorably      Very favorably      Very favorably
# 6  Very unfavorably  Somewhat favorably  Somewhat favorably

# %% [markdown]
# We will start cleaning the data by transforming some values:

# %%
df=df.dropna(subset=['Gender']).dropna(subset=df.columns[1:],how='all')
rate=pd.Series(['Very unfavorably','Somewhat unfavorably','Neither favorably nor unfavorably (neutral)','Somewhat favorably','Very favorably'])
df[col[1:]]=df[col[1:]].applymap(lambda x: np.nan if x is np.nan else rate.index[rate==x][0]).astype(float)
df.head()

# %%
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# We will finally aggregate the data into a more efficient table:

# %%
df=df.pivot_table(values=col[1:],columns='Gender',aggfunc=['mean','count'])
df.columns = df.columns.swaplevel(0, 1)
df=df.sort_index(axis=1, level=0,ascending=False)
df
# Out:
# Gender                    Male          Female
#                           mean count      mean count
# Anakin Skywalker      2.654731   391  2.892857   364
# Boba Fett             2.486559   372  2.176871   294
# C-3P0                 3.242718   412  3.578125   384
# Darth Vader           2.749392   411  2.197436   390
# Emperor Palpatine     2.212291   358  1.874126   286
# Han Solo              3.675545   413  3.677922   385
# Jar Jar Binks         1.548387   372  2.024615   325
# Lando Calrissian      2.653740   361  2.614865   296
# Luke Skywalker        3.563549   417  3.612245   392
# Obi Wan Kenobi        3.634568   405  3.643411   387
# Padme Amidala         2.530612   343  2.687285   291
# Princess Leia Organa  3.528846   416  3.590793   391
# R2 D2                 3.444444   414  3.712821   390
# Yoda                  3.577017   409  3.698210   391

# %% [markdown]
# Use the final table to finally visualize rates on Star Wars Characters from total respondents:

# %%
df.loc[:,(slice(None),'count')].plot.barh(cmap='cool',legend=False,title='Familiar')

# %%
df.loc[:,(slice(None),'mean')].plot.barh(cmap='cool',legend=False,xlim=(0,4),title='Rate')

# %% [markdown]
# End. Thankyou!
